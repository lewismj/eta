# %% [markdown]
# # Blackjack Demo Notebook
#
# Run this from the `demo/blackjack/blackjack-demo` package context so imports resolve.
#
# This notebook is a clear 3-step workbook.

# %%
(import blackjack_workbook)
(workbook-overview)

# %% [markdown]
# ## Step Map
#
# - Step 1 uses simulation from `blackjack/src/mc.eta`.
# - Step 2 uses causal evaluation from `blackjack/src/causal.eta`.
# - Step 3 does learning in `blackjack/src/learn.eta`, then policy rendering from `blackjack/src/strategy.eta` and `blackjack/src/maxims.eta`.

# %%
(workbook-steps)

# %% [markdown]
# ## Step 1: Generate a Small Trace
#
# Purpose: produce deterministic rollout data and summary metrics.

# %%
(run-step-1 42 64 1)

# %% [markdown]
# ## Step 2: Causal Sweep for One Decision
#
# Purpose: evaluate `do(hit)` vs `do(stand)` for state `(16,10)` across count buckets.

# %%
(run-step-2 42 16 10)

# %% [markdown]
# ## Step 3: Learning and Policy Artifacts
#
# Purpose: run supervised weight recovery, then preview chart and maxims.

# %%
(run-step-3 42 8 32 0.01 4)

# %% [markdown]
# ## Optional: Run All Steps Together

# %%
(run-workbook 42)
