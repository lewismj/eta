# %% [markdown]
# # Blackjack Demo Notebook
#
# Run this from the `demo/blackjack/blackjack-demo` package context so imports resolve.

# %%
(import blackjack_demo)
(startup-message)

# %%
(run-command '("causal" "--config" "tests/config/supervised_demo.json"))

# %%
(run-command '("learn" "--config" "tests/config/supervised_demo.json"))

# %%
(run-command '("chart" "--config" "tests/config/supervised_demo.json"))

# %%
(run-command '("maxims" "--config" "tests/config/supervised_demo.json"))
